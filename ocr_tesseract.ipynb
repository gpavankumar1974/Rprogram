# %% [markdown]
# # install.packages("tesseract")

# %%
library(imager)
#file <- system.file('C:/Users/radha/Desktop/Alex Outputs/Q1  Graphs/q1_tukey_model1.jpg',package='imager')
#system.file gives the full path for a file that ships with a R package
#if you already have the full path to the file you want to load just run:
im <- load.image("C:/Users/radha/Desktop/Alex Outputs/Q1  Graphs/q1_tukey_model1.jpg")
#im <- load.image(file)

plot(im) #Parrots!
# Out:
# Plot with title ""

# %%
library(tesseract)
library(magick)


input <- image_read("C:\\Users\\radha\\Desktop\\Alex Outputs\\Q1  Graphs\\q1_tukey_model1.jpg")

text <- input %>%
  image_resize("2000x") %>%
  image_convert(type = 'Grayscale') %>%
  image_trim(fuzz = 40) %>%
  image_write(format = 'png', density = '300x300') %>%
  tesseract::ocr() 

cat(text)
# Out:
# > TukeyHSD(mode11, conf.1eve1 = 0.99)
# Tukey mu1tip1e comparisons of means
# 99% fami1y—wise confidence 1eve1
# Fit: aov(formu1a = ana1ysis.anova$dea1_probabi1ity ~ ana1ysis.anovaSparent_category_name)
# S‘ana1ysis.anovaSparent_category_name‘
# diff 1wr upr p adj
# Consumer e1ectronics—Anima1s —0.061654111 —0.066951182 —0.056357040 0.000000
# For busineSS—Anima1s —0.125151152 —0.134313720 —0.115988583 0.000000
# For home and cottages—Animals —0.057029190 —0.062308444 —0.051749935 0.000000
# Hobbies and Recreation—Anima1s —0.113407637 —0.119293398 —0.107521876 0.000000
# Persona] thingS—Anima1s —O.160654379 —0.165466692 —0.155842067 0.000000
# The property—Anima1s —0.094596476 —0.099975594 —0.089217359 0.000000
# The services—Anima1s 0.165782127 0.159529182 0.172035073 0.000000
# Transport—Anima1s 0.025403034 0.019432776 0.031373292 0.000000
# For business—Consumer e1ectronics —0.063497041 —0.071799768 —0.055194314 0.000000
# For home and cottages—Consumer e1ectronics 0.004624921 0.001039794 0.008210049 0.000126
# Hobbies and Recreation-consumer e1ectronics -0.051753526 -0.056183515 -0.047323538 0.000000
# Persona] things-Consumer e1ectronics -0.099000268 -0.101853505 -0.096147031 0.000000
# The property-Consumer e1ectronics -0.032942366 -0.036672984 -0.029211747 0.000000
# The services-consumer electronics 0.227436238 0.222528903 0.232343574 0.000000
# Transport-consumer e1ectronics 0.087057145 0.082515494 0.091598796 0.000000
# For home and cottages-For business 0.068121962 0.059830591 0.076413334 0.000000
# Hobbies and Recreation-For business 0.011743515 0.003053377 0.020433653 0.000043
# Persona] thingS-For business -0.035503227 -0.043505394 -0.027501061 0.000000
# The property-For business 0.030554675 0.022199365 0.038909986 0.000000
# The services-For business 0.290933279 0.281990369 0.299876189 0.000000
# Transport-For business 0.150554186 0.141806598 0.159301773 0.000000
# Hobbies and Recreation-For home and cottages -0.056378447 -0.060787117 -0.051969778 0.000000
# Persona] things-For home and cottages -0.103625189 -0.106445213 -0.100805166 0.000000
# The property-For home and cottages -0.037567287 -0.041272565 -0.033862009 0.000000
# The services-For home and cottages 0.222811317 0.217923218 0.227699416 0.000000
# Transport-For home and cottages 0.082432223 0.077911365 0.086953082 0.000000
# Persona1 things-Hobbies and Recreation -0.047246742 -0.051083953 -0.043409531 0.000000
# The property-Hobbies and Recreation 0.018811161 0.014283386 0.023338935 0.000000
# The services-Hobbies and Recreation 0.279189764 0.273652150 0.284727379 0.000000
# Transport-Hobbies and Recreation 0.138810671 0.133594368 0.144026974 0.000000
# The property-Persona1 things 0.066057903 0.063055086 0.069060719 0.000000
# The services-Persona1 things 0.326436507 0.322056856 0.330816157 0.000000
# Transport-Persona1 things 0.186057413 0.182091813 0.190023013 0.000000
# The services-The property 0.260378604 0.255382817 0.265374391 0.000000
# Transport-The property 0.119999510 0.115362427 0.124636593 0.000000
# Transport-The services -O.140379094 -0.146006434 -0.1347517S3 0.000000
