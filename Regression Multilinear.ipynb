# %%
library(sqldf)
datareg  <- read.csv.sql("C:\\Users\\radha\\Desktop\\Alex Outputs\\diffReg.csv", 
                         "select * from file ", sep=",")

# %%
summary(datareg)
# Out:
#       diff        citationFlow     trustFlow     facebookShares
#  Min.   : 5.00   Min.   : 1.00   Min.   : 0.00   Min.   :     0.0
#  1st Qu.:31.00   1st Qu.:16.00   1st Qu.: 8.00   1st Qu.:     0.0
#  Median :44.00   Median :28.00   Median :18.00   Median :     5.5
#  Mean   :43.36   Mean   :27.22   Mean   :19.73   Mean   :  1909.6
#  3rd Qu.:56.00   3rd Qu.:37.00   3rd Qu.:28.00   3rd Qu.:   147.0
#  Max.   :86.00   Max.   :80.00   Max.   :85.00   Max.   :819199.0
#  externalBackLinks    refDomains           refIPs
#  Min.   :       0   Min.   :     0.0   Min.   :    0.00
#  1st Qu.:       1   1st Qu.:     1.0   1st Qu.:    1.00
#  Median :      24   Median :     7.0   Median :    7.00
#  Mean   :   16994   Mean   :   187.6   Mean   :   96.45
#  3rd Qu.:     303   3rd Qu.:    39.0   3rd Qu.:   35.00
#  Max.   :16635975   Max.   :103904.0   Max.   :50376.00

# %%
linearMod <- lm(diff ~ citationFlow +	trustFlow +	facebookShares+
                  externalBackLinks+	refDomains+	refIPs, data=datareg) 
print(linearMod)
# Out:
# Call:
# lm(formula = diff ~ citationFlow + trustFlow + facebookShares +
#     externalBackLinks + refDomains + refIPs, data = datareg)
#
# Coefficients:
#       (Intercept)       citationFlow          trustFlow     facebookShares
#         3.183e+01          4.570e-01         -5.531e-02          1.094e-05
# externalBackLinks         refDomains             refIPs
#        -8.654e-06          6.201e-04          1.924e-03

# %%
summary(linearMod)
# Out:
# Call:
# lm(formula = diff ~ citationFlow + trustFlow + facebookShares +
#     externalBackLinks + refDomains + refIPs, data = datareg)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -32.478 -12.402  -0.209  11.600  42.749
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        3.183e+01  6.334e-01  50.252  < 2e-16 ***
# citationFlow       4.570e-01  3.348e-02  13.652  < 2e-16 ***
# trustFlow         -5.531e-02  2.911e-02  -1.900 0.057527 .
# facebookShares     1.094e-05  1.233e-05   0.887 0.375022
# externalBackLinks -8.654e-06  2.410e-06  -3.591 0.000335 ***
# refDomains         6.201e-04  4.637e-04   1.337 0.181295
# refIPs             1.924e-03  1.260e-03   1.526 0.127004
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 14.85 on 2983 degrees of freedom
# Multiple R-squared:  0.1385,	Adjusted R-squared:  0.1368
# F-statistic: 79.92 on 6 and 2983 DF,  p-value: < 2.2e-16

# %% [markdown]
# <h3> Multiple R-squared:  0.1385 </h3> Ver Low

# %%
linearModCor <- cor.test(datareg$diff , datareg$citationFlow, method = "pearson") 
print(linearModCor)
# Out:
# 	Pearson's product-moment correlation
#
# data:  datareg$diff and datareg$citationFlow
# t = 21.253, df = 2988, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.3308256 0.3931144
# sample estimates:
#       cor
# 0.3623746

# %%
linearModCor <- cor.test(datareg$diff , datareg$trustFlow , method = "pearson") 
print(linearModCor)
# Out:
# 	Pearson's product-moment correlation
#
# data:  datareg$diff and datareg$trustFlow
# t = 15.623, df = 2988, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.2413432 0.3076279
# sample estimates:
#      cor
# 0.274812

# %%
linearModCor <- cor.test(datareg$diff , datareg$facebookShares , method = "pearson") 
print(linearModCor)
# Out:
# 	Pearson's product-moment correlation
#
# data:  datareg$diff and datareg$facebookShares
# t = 3.8504, df = 2988, p-value = 0.0001204
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.03450601 0.10584510
# sample estimates:
#       cor
# 0.0702654

# %%
linearModCor <- cor.test(datareg$diff , datareg$externalBackLinks , method = "pearson") 
print(linearModCor)
# Out:
# 	Pearson's product-moment correlation
#
# data:  datareg$diff and datareg$externalBackLinks
# t = 3.6373, df = 2988, p-value = 0.0002802
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.03061998 0.10199696
# sample estimates:
#        cor
# 0.06639341

# %%
linearModCor <- cor.test(datareg$diff , datareg$refDomains , method = "pearson") 
print(linearModCor)
# Out:
# 	Pearson's product-moment correlation
#
# data:  datareg$diff and datareg$refDomains
# t = 6.1837, df = 2988, p-value = 7.115e-10
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.07687072 0.14765860
# sample estimates:
#       cor
# 0.1124073

# %%
linearModCor <- cor.test(datareg$diff , datareg$refIPs , method = "pearson")
print(linearModCor)
# Out:
# 	Pearson's product-moment correlation
#
# data:  datareg$diff and datareg$refIPs
# t = 6.1469, df = 2988, p-value = 8.952e-10
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.07620578 0.14700427
# sample estimates:
#       cor
# 0.1117468

# %%
library(gclus)
dta <- datareg[c(2,3,4,5,6,7)] # get data 
dta.r <- abs(cor(dta)) # get correlations
dta.col <- dmat.color(dta.r) # get colors
# reorder variables so those with highest correlation
# are closest to the diagonal
dta.o <- order.single(dta.r) 
cpairs(dta, dta.o, panel.colors=dta.col, gap=.5,
main="Variables Ordered and Colored by Correlation" )
# Out:
# plot without title

# %% [markdown]
# <h2> Very Low Correlation </h2>
# <h3>
# In this, some good are
# citationFlow  - 0.36
# trustFlow - 0.27
#
# this is poor correlation for "Diff" columns. So none is suitable for prediction.
# even after Excluding "zeros" facebookShares , externalBackLinks, refDomains, refIPs, still it does not improve predictability.
#
# </h3>

# %%
linearMod <- lm(diff ~ (citationFlow*trustFlow *facebookShares * externalBackLinks*refDomains+refIPs), data=datareg) 
summary(linearMod)
# Out:
# Call:
# lm(formula = diff ~ (citationFlow * trustFlow * facebookShares *
#     externalBackLinks * refDomains + refIPs), data = datareg)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -42.131 -12.052  -0.157  11.342  40.242
#
# Coefficients:
#                                                                      Estimate
# (Intercept)                                                         3.442e+01
# citationFlow                                                        3.502e-01
# trustFlow                                                          -2.958e-01
# facebookShares                                                      3.338e-04
# externalBackLinks                                                   1.894e-04
# refDomains                                                          4.361e-02
# refIPs                                                              8.032e-03
# citationFlow:trustFlow                                              6.025e-03
# ...
